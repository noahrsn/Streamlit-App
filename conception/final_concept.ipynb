# %% [markdown]
# # 🌍 „Degrees of No Return“
#
# Der Klimawandel wird in der öffentlichen und politischen Diskussion meist über **globale Kennzahlen** beschrieben, etwa über eine durchschnittliche Erderwärmung oder einen prognostizierten Meeresspiegelanstieg. Obwohl diese Werte wissenschaftlich fundiert sind, bleiben sie für viele Menschen abstrakt und schwer greifbar. Für lokale Entscheidungsträger, Versicherungen oder private Immobilienbesitzer stellt sich jedoch weniger die Frage nach globalen Mittelwerten, sondern vielmehr nach den konkreten Auswirkungen vor Ort. Es fehlt bislang ein niedrigschwelliges, visuell verständliches Werkzeug, das **globale Klimamodelle** in **lokal interpretierbare Risikobilder** übersetzt und damit eine Brücke zwischen wissenschaftlicher Modellierung und praktischer Entscheidungsfindung schlägt. Genau an dieser Stelle setzt das Projekt **„Degrees of No Return“** an.
#
# ### 🔬 Zentrale Forschungsfrage
#
# Die leitende Forschungsfrage dieses Projekts lautet:
#
# „*Wie kann ich globale Klimamodelle und Emissionsszenarien so umsetzen, modellieren und visualisieren, dass sie für eine konkrete Region bis zum Jahr 2050 verständliche und belastbare Aussagen über **Überflutungsrisiken** und die Häufigkeit von **Hitzetagen** liefern und dabei auch für Nicht‑Experten intuitiv nutzbar sind?*“
#
# Im Mittelpunkt steht dabei nicht nur die Modellgüte, sondern insbesondere die Frage, wie komplexe wissenschaftliche Ergebnisse so aufbereitet werden können, dass sie Entscheidungen auf lokaler Ebene unterstützen.
#
# ### 🧭 Thematische Unterfragen
#
# Zur strukturierten Bearbeitung der Forschungsfrage werden drei thematische Unterfragen definiert:
#
# * *Erstens: *Wie kann ich historische Temperatur- und CO₂-Daten mithilfe von Machine‑Learning‑Zeitreihenmodellen so verknüpfen, dass sich die zukünftige Entwicklung der lokalen Durchschnittstemperatur und die Anzahl von **Hitzetagen** bis 2050 unter verschiedenen Emissionsannahmen prognostizieren lassen?*
#
# * *Zweitens: *Wie kann ich **globale Meeresspiegelprojektionen** mit hochaufgelösten topographischen Daten kombinieren, um daraus eine räumlich präzise Abschätzung des lokalen **Überflutungsrisikos** für eine konkrete Region abzuleiten?*
#
# * *Drittens: *Wie kann ich die Ergebnisse aus Temperatur- und Meeresspiegelmodellierung zu einem integrierten lokalen **Risikobild** zusammenführen, das auch Extremwetterereignisse verständlich kommuniziert und vergleichbar macht?*
#
# ### 🎯 Zielgruppe und Anwendungsnutzen
#
# Die Anwendung richtet sich an kommunale Stadt‑ und Raumplaner, die potenziell gefährdete Infrastrukturen identifizieren und langfristige Anpassungsmaßnahmen planen möchten, an Versicherungsanalysten zur datenbasierten Bewertung von Immobilien‑ und Portfoliorisiken sowie an private Immobilienbesitzer, die ihre persönliche Betroffenheit besser einschätzen wollen. Der Mehrwert liegt darin, abstrakte Klimadaten in konkrete, visuelle und numerische Aussagen zu übersetzen, etwa in Form von prognostizierten **Überflutungsflächen** oder der erwarteten Zunahme von **Hitzetagen** an einem bestimmten Ort.
#
# ### 🤖 Machine‑Learning‑Prozess und Modelllogik
#
# Im Zentrum des Projekts steht ein mehrstufiger **Machine‑Learning‑Prozess**. Zunächst werden historische Temperatur‑, CO₂‑ und Meeresspiegeldaten bereinigt, vereinheitlicht und zeitlich synchronisiert. Auf dieser Basis werden Zeitreihenmodelle trainiert, die den Zusammenhang zwischen Emissionsentwicklung und lokaler Temperaturveränderung erlernen. Die Modelle werden auf historischen Daten validiert und anhand klar definierter Qualitätsmetriken bewertet, insbesondere mit dem Ziel, für Temperaturprognosen einen **RMSE von unter 0,2 °C** auf Testdaten zu erreichen. Die prognostizierten Temperaturverläufe werden anschließend genutzt, um die zukünftige Anzahl von **Hitzetagen** zu berechnen und als Kennzahl auszugeben.
#
# Parallel dazu werden Meeresspiegelprojektionen auf digitale Höhenmodelle projiziert, um potenzielle **Überflutungsflächen** zu berechnen. Diese werden mit offiziellen Hochwassergefahrenkarten verglichen, wobei eine räumliche Übereinstimmung von mindestens **85 %** angestrebt wird. Insgesamt folgt der ML‑Prozess einem klaren Zyklus aus Datenaufbereitung, Modelltraining, Validierung, Szenarien‑Simulation und visueller sowie numerischer Ausgabe.
#
# ### 🖥️ Umsetzungskonzept und WebApp‑Skizze
#
# Als finales Produkt entsteht eine interaktive **Streamlit‑WebApp** mit dem Titel **„Degrees of No Return“**. Das Herzstück der Anwendung ist eine **interaktive Weltkarte**, die es ermöglicht, Klimarisiken zunächst auf globaler Ebene zu betrachten und anschließend stufenlos auf regionale und lokale Maßstäbe herunterzuzoomen. Beim Start der Anwendung sieht der Nutzer die Erde in einer neutralen Projektion, überlagert mit einer dynamischen Klimaschicht. Diese Schicht visualisiert wahlweise Temperaturabweichungen, die Häufigkeit von **Hitzetagen** oder potenzielle **Überflutungsflächen**. Mit zunehmendem Zoom‑Level werden die Daten feiner aufgelöst, sodass globale Trends schrittweise in konkrete lokale Auswirkungen übersetzt werden. Farben, Intensitäten und Flächen reagieren in Echtzeit auf Interaktionen und vermitteln ein unmittelbares Gefühl für die räumliche Dimension des Klimawandels.
#
# Ergänzend zur Karte werden zentrale Kennzahlen direkt eingeblendet. Dazu gehören unter anderem die prognostizierte durchschnittliche Temperaturänderung bis 2050, die erwartete Anzahl von **Hitzetagen** pro Jahr sowie der geschätzte Anteil der betrachteten Fläche, der potenziell von **Überflutung** betroffen ist. Diese Kennzahlen passen sich dynamisch an den gewählten Ort, den Zeitpunkt und das aktive Szenario an und übersetzen visuelle Eindrücke in konkrete Zahlen.
#
# Unterhalb der Karte befindet sich ein **Zeit‑Slider**, der den Zeitraum von der Vergangenheit bis 2050 abdeckt. Seitlich ist ein Kontrollpanel angeordnet, über das Nutzer zwischen verschiedenen Datenebenen wechseln können. Ein zentrales Element dieses Panels ist der **Szenario‑Switch**. Er ermöglicht den Vergleich zwischen einer Fortschreibung der aktuellen Entwicklung ohne wesentliche Änderungen im Emissionsverhalten und einem Szenario, das von der Einhaltung definierter Klimaziele ausgeht. Beim Umschalten werden sämtliche Modellannahmen angepasst, wodurch sich sowohl die Karte als auch die Kennzahlen unmittelbar verändern. Auf diese Weise wird sichtbar, wie stark sich zukünftige Risiken durch heutige Entscheidungen beeinflussen lassen.
#
# ### 🗂️ Datengrundlage
#
# Die Datengrundlage des Projekts besteht aus mehreren etablierten und frei zugänglichen Quellen. Für die Temperaturentwicklung werden unter anderem der Datensatz **Earth Surface Temperature Data** von Kaggle (https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data) sowie die **GISS Surface Temperature Analysis** der NASA (https://data.giss.nasa.gov/gistemp/) genutzt. Die atmosphärischen CO₂‑Konzentrationen stammen aus den Messreihen der **NOAA** am Mauna‑Loa‑Observatorium (https://gml.noaa.gov/ccgg/trends/). Informationen zum globalen Meeresspiegel werden aus den **Sea Level Change Data** der NASA bezogen (https://sealevel.nasa.gov/) und durch Projektionen des **IPCC** ergänzt. Für die lokale Überflutungsmodellierung kommen digitale Höhenmodelle wie die **SRTM‑Daten** von **OpenTopography** (https://opentopography.org/) oder das **Copernicus DEM** (https://spacedata.copernicus.eu/) zum Einsatz. Durch die Kombination dieser Datenquellen entsteht eine robuste, transparente und wissenschaftlich fundierte Basis für die Modellierung und Visualisierung lokaler Klimarisiken.
